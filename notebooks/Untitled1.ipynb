# %%
import PIL
import matplotlib.pyplot as plt
import glob

# %%
input_size = 224
trans = transforms.Compose([
#         transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
    ])

# %%
trans(pbc)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F00AC3E1DF0>

# %%
from torchvision import datasets, models, transforms

# %%
monocytes_pbc = glob.glob('/hddraid5/data/colin/cell_classification/data/PBC_dataset_normal_DIB/monocyte/*.jpg')

# %%
duke_images = glob.glob('/hddraid5/data/colin/covid-data/COVID Research Images/**/*.jpg', recursive=True)

# %%
fig, axs = plt.subplots(nrows=10, ncols=2, figsize=(4,25))
for i in range(10):
    pbc = PIL.Image.open(monocytes_pbc[i])
    duke = PIL.Image.open(duke_images[i])
    axs[i][0].imshow(trans(pbc))
    axs[i][1].imshow(trans(duke))
